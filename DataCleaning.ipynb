# %% [markdown]
# # Data Cleaning Demo Project

# %% [markdown]
# # Steps are:-
#
# - Import data and assign appropriate datatype based on sample data
# - Detecting and treating missing values
# - Look for rows that need to be cleaned and trimmed.
# - Please data cleaning report and share it with the client

# %%
# Importing libraries
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

# %%
myfile = 'assets/PRICES-STOCK.csv'
BranchProductdata = pd.read_csv(myfile,sep='|')

# %%
BranchProductdata.head()
# Out:
#       SKU BRANCH  PRICE  STOCK
# 0  142308    HRO   45.6      3
# 1  223240   RHSM   15.3      5
# 2   49514   RHSM   56.7     -2
# 3  111807   RHSM   48.0     -4
# 4  223543     MS    8.7     -1

# %%
# Out:
# 2296767

# %% [markdown]
# ### Check null cases

# %%
BranchProductdata.isnull().sum()/len(BranchProductdata)*100
# Out:
# SKU        0.000000
# BRANCH    19.960884
# PRICE      0.000000
# STOCK      0.000000
# dtype: float64

# %% [markdown]
# ## Key Findings
#
# - Branch information is not available for 19.96% of the record. Upon analysis, we decided to remove those records as it did not give any significant insight to the data. Sample rows has been attached in the email.

# %% [markdown]
# ## Analyse the null cases

# %%
BranchProductdataNullCases = BranchProductdata[BranchProductdata['BRANCH'].notnull()]
BranchProductdataNullCases
# Out:
#             SKU BRANCH  PRICE  STOCK
# 0        142308    HRO   45.6      3
# 1        223240   RHSM   15.3      5
# 2         49514   RHSM   56.7     -2
# 3        111807   RHSM   48.0     -4
# 4        223543     MS    8.7     -1
# ...         ...    ...    ...    ...
# 2296762  243017    HRO   73.2      4
# 2296763  185713     MS   85.5      2
# 2296764  296517   RHSM   59.4      3
# 2296765   52814     MS   23.7     -1
# 2296766  196940     MM    4.5      5
#
# [1838312 rows x 4 columns]

# %% [markdown]
# ## Filter to take 'MM' and 'RHSM' branch

# %%
BranchFilter = BranchProductdataNullCases.loc[BranchProductdataNullCases['BRANCH'].isin(['MM','RHSM'])]
set(BranchFilter['BRANCH'])
# Out:
# {'MM', 'RHSM'}

# %% [markdown]
# # Import Product data

# %%
Productfile = 'assets/PRODUCTS.csv'
Productdata = pd.read_csv(Productfile,sep='|')

# %%
Productdata.head()
# Out:
#       SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 0   52572       UN                  B          NaN         False
# 1  278100      NaN                  R          NaN          True
# 2   27404       KG                  B          NaN          True
# 3  215143       UN                 CD            Y          True
# 4   85805       KG                 CD            N         False
#
#    FINELINE_NUMBER       BARCODES                                 NAME  \
# 0           713115   693177767936                             CANASTOS
# 1           345827            399                   LIMÓN COLIMA KG
# 2           134923   762230099043                              CHICLES
# 3           773663  7501199416236  JABON LIQUIDO PARA MANOS VITAMINA E
# 4           233313  8410113003119   VINO TINTO GRAN CORONAS TORRES 750
#
#                                          DESCRIPTION  \
# 0                     <p>CANASTO CONEJO F1 A 1UN</p>
# 1                          <p>LIMÓN COLIMA KG   </p>
# 2                       <p>TRIDENT 6S SANDIA 9GR</p>
# 3  <p>JABON LIQUIDO PARA MANOS VITAMINA E 442 ML....
# 4    <p>VINO TINTO GRAN CORONAS TORRES 750 1 PZA</p>
#
#                                            IMAGE_URL       CATEGORY  \
# 0  https://locahost:8000/images/693177767936?heig...        APPAREL
# 1  https://locahost:8000/images/399?height=500&wi...  ENTERTAINMENT
# 2  https://locahost:8000/images/762230099043?heig...      HARDLINES
# 3  https://locahost:8000/images/7501199416236?hei...      HARDLINES
# 4  https://locahost:8000/images/8410113003119?hei...    CONSUMABLES
#
#           SUB_CATEGORY          SUB_SUB_CATEGORY           BRAND
# 0            MENS WEAR            MEN - T-SHIRTS  PUPPY DOG PALS
# 1       TOYS & HOBBIES                  PELUCHES        ENTRECOT
# 2           AUTOMOTIVE      APARIENCIA AUTOMOVIL           SPURA
# 3             SEASONAL         SEASONAL - EASTER         CHAMYTO
# 4  HOUSEHOLD CHEMICALS  AIR FRESHENER-DEODORIZER         POOPSIE

# %%
Productdata.dtypes
# Out:
# SKU                    int64
# BUY_UNIT              object
# DESCRIPTION_STATUS    object
# ORGANIC_ITEM          object
# KIRLAND_ITEM            bool
# FINELINE_NUMBER        int64
# BARCODES               int64
# NAME                  object
# DESCRIPTION           object
# IMAGE_URL             object
# CATEGORY              object
# SUB_CATEGORY          object
# SUB_SUB_CATEGORY      object
# BRAND                 object
# dtype: object

# %%
Productdata['BUY_UNIT'] = Productdata['BUY_UNIT'].astype('category')
Productdata['DESCRIPTION_STATUS'] = Productdata['DESCRIPTION_STATUS'].astype('category')
Productdata['BRAND'] = Productdata['BRAND'].astype('category')

# %%
Productdata.select_dtypes(include = 'number').head()
# Out:
#       SKU  FINELINE_NUMBER       BARCODES
# 0   52572           713115   693177767936
# 1  278100           345827            399
# 2   27404           134923   762230099043
# 3  215143           773663  7501199416236
# 4   85805           233313  8410113003119

# %% [markdown]
# ### Analyze null cases

# %%
Productdata.isnull().sum()/len(Productdata)*100
# Out:
# SKU                    0.000000
# BUY_UNIT              33.303581
# DESCRIPTION_STATUS    20.068296
# ORGANIC_ITEM          33.330327
# KIRLAND_ITEM           0.000000
# FINELINE_NUMBER        0.000000
# BARCODES               0.000000
# NAME                   0.003732
# DESCRIPTION            0.000000
# IMAGE_URL              0.000000
# CATEGORY               0.459038
# SUB_CATEGORY           0.459038
# SUB_SUB_CATEGORY       0.459038
# BRAND                  0.041052
# dtype: float64

# %%
Productdata2 = Productdata[Productdata['ORGANIC_ITEM'].isnull()]
Productdata2
# Out:
#            SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 0        52572       UN                  B          NaN         False
# 1       278100      N/A                  R          NaN          True
# 2        27404       KG                  B          NaN          True
# 12        9510       KG                NaN          NaN          True
# 21      191131       KG                  B          NaN         False
# ...        ...      ...                ...          ...           ...
# 321532  141957      N/A                 CD          NaN         False
# 321533   57936       UN                  B          NaN         False
# 321536  127410       UN                 CD          NaN          True
# 321540  312844       KG                  B          NaN          True
# 321541   60891       UN                NaN          NaN          True
#
#         FINELINE_NUMBER       BARCODES                              NAME  \
# 0                713115   693177767936                          CANASTOS
# 1                345827            399                LIMÓN COLIMA KG
# 2                134923   762230099043                           CHICLES
# 12               686777   780413300603                 HUEVO TRADICIONAL
# 21               938864  7501198350944                   BEBIDA TE LIMON
# ...                 ...            ...                               ...
# 321532           215603  8033737232095                    PIMIENTA NEGRA
# 321533           321437    40000680310               BERMUDA JEANS DENIM
# 321536           285494  2502200000005           QUESO MOSARELLA ADOBADO
# 321540           305744  6971165068775  CAMISA JORDACHE J, BLANCO, EG/XL
# 321541           975067    40000695373                              SOFA
#
#                                     DESCRIPTION  \
# 0                <p>CANASTO CONEJO F1 A 1UN</p>
# 1                     <p>LIMÓN COLIMA KG   </p>
# 2                  <p>TRIDENT 6S SANDIA 9GR</p>
# 12               <p>H.PRIMERA COLOR.12 12UN</p>
# 21               <p>BEBIDA TE LIMON 473 ML.</p>
# ...                                         ...
# 321532             <p>PIMIENTA NEGRA 80 GRS</p>
# 321533               <p>BERMUDA LINEA 2 1UN</p>
# 321536     <p>QUESO MOSARELLA ADOBADO 0 NDF</p>
# 321540  <p>CAMISA JORDACHE J, BLANCO, EG/XL</p>
# 321541           <p>SOFA SOC T-PU CHOCO 1UN</p>
#
#                                                 IMAGE_URL       CATEGORY  \
# 0       https://locahost:8000/images/693177767936?heig...        APPAREL
# 1       https://locahost:8000/images/399?height=500&wi...  ENTERTAINMENT
# 2       https://locahost:8000/images/762230099043?heig...      HARDLINES
# 12      https://locahost:8000/images/780413300603?heig...           HOME
# 21      https://locahost:8000/images/7501198350944?hei...     BABY WORLD
# ...                                                   ...            ...
# 321532  https://locahost:8000/images/8033737232095?hei...      HARDLINES
# 321533  https://locahost:8000/images/40000680310?heigh...        GROCERY
# 321536  https://locahost:8000/images/2502200000005?hei...        APPAREL
# 321540  https://locahost:8000/images/6971165068775?hei...        GROCERY
# 321541  https://locahost:8000/images/40000695373?heigh...    MEAT & FISH
#
#             SUB_CATEGORY              SUB_SUB_CATEGORY               BRAND
# 0              MENS WEAR                MEN - T-SHIRTS      PUPPY DOG PALS
# 1         TOYS & HOBBIES                      PELUCHES            ENTRECOT
# 2             AUTOMOTIVE          APARIENCIA AUTOMOVIL               SPURA
# 12               BEDDING               CAMA ACCESORIOS            IMPRECOO
# 21      INFANT SOFTLINES                        BOTTOM           CASA LOBO
# ...                  ...                           ...                 ...
# 321532     LAWN & GARDEN                     MACETEROS               DELIA
# 321533    DAIRY PRODUCTS                         CREAM            SAN JOSE
# 321536             SOCKS             LADY - CALCETINES  MY LITTLE BOUTIQUE
# 321540        92 GROCERY  MILK-CREAM-SUBSTITUTES-SHELF               MEYER
# 321541           SEAFOOD                SEAFOOD - FISH              TAIWAN
#
# [107171 rows x 14 columns]

# %%
Productdata['BUY_UNIT'] = Productdata['BUY_UNIT'].fillna('N/A')
Productdata['DESCRIPTION_STATUS'] = Productdata['DESCRIPTION_STATUS'].fillna('N/A')
Productdata['ORGANIC_ITEM'] = Productdata['ORGANIC_ITEM'].fillna('N/A')

# %%
Productdata.isnull().sum()
# Out:
# SKU                      0
# BUY_UNIT                 0
# DESCRIPTION_STATUS       0
# ORGANIC_ITEM             0
# KIRLAND_ITEM             0
# FINELINE_NUMBER          0
# BARCODES                 0
# NAME                    12
# DESCRIPTION              0
# IMAGE_URL                0
# CATEGORY              1476
# SUB_CATEGORY          1476
# SUB_SUB_CATEGORY      1476
# BRAND                  132
# dtype: int64

# %%
Productdata['DESCRIPTION'] = Productdata['DESCRIPTION'].replace({'<p>':'','</p>':''},regex = True)
Productdata
# Out:
#            SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 0        52572       UN                  B          N/A         False
# 1       278100      N/A                  R          N/A          True
# 2        27404       KG                  B          N/A          True
# 3       215143       UN                 CD            Y          True
# 4        85805       KG                 CD            N         False
# ...        ...      ...                ...          ...           ...
# 321537   37542       UN                N/A            N         False
# 321538  199851      N/A                  R            Y          True
# 321539  144269      N/A                  R            Y          True
# 321540  312844       KG                  B          N/A          True
# 321541   60891       UN                N/A          N/A          True
#
#         FINELINE_NUMBER       BARCODES                                 NAME  \
# 0                713115   693177767936                             CANASTOS
# 1                345827            399                   LIMÓN COLIMA KG
# 2                134923   762230099043                              CHICLES
# 3                773663  7501199416236  JABON LIQUIDO PARA MANOS VITAMINA E
# 4                233313  8410113003119   VINO TINTO GRAN CORONAS TORRES 750
# ...                 ...            ...                                  ...
# 321537           966232   698400300544                      LOZA BASICA GRA
# 321538           855034  7501199404301             DETERGENTE LIQUIDO COLOR
# 321539           434058  7501006555752      2 SOBRES PALOMITAS  + VALENTINA
# 321540           305744  6971165068775     CAMISA JORDACHE J, BLANCO, EG/XL
# 321541           975067    40000695373                                 SOFA
#
#                                         DESCRIPTION  \
# 0                           CANASTO CONEJO F1 A 1UN
# 1                                LIMÓN COLIMA KG
# 2                             TRIDENT 6S SANDIA 9GR
# 3       JABON LIQUIDO PARA MANOS VITAMINA E 442 ML.
# 4          VINO TINTO GRAN CORONAS TORRES 750 1 PZA
# ...                                             ...
# 321537                       TAZA CONSOME 280CC 1UN
# 321538                DETERGENTE LIQUIDO COLOR 5 LT
# 321539        2 SOBRES PALOMITAS  + VALENTINA 1 PZA
# 321540             CAMISA JORDACHE J, BLANCO, EG/XL
# 321541                      SOFA SOC T-PU CHOCO 1UN
#
#                                                 IMAGE_URL       CATEGORY  \
# 0       https://locahost:8000/images/693177767936?heig...        APPAREL
# 1       https://locahost:8000/images/399?height=500&wi...  ENTERTAINMENT
# 2       https://locahost:8000/images/762230099043?heig...      HARDLINES
# 3       https://locahost:8000/images/7501199416236?hei...      HARDLINES
# 4       https://locahost:8000/images/8410113003119?hei...    CONSUMABLES
# ...                                                   ...            ...
# 321537  https://locahost:8000/images/698400300544?heig...      HARDLINES
# 321538  https://locahost:8000/images/7501199404301?hei...        GROCERY
# 321539  https://locahost:8000/images/7501006555752?hei...  ENTERTAINMENT
# 321540  https://locahost:8000/images/6971165068775?hei...        GROCERY
# 321541  https://locahost:8000/images/40000695373?heigh...    MEAT & FISH
#
#                SUB_CATEGORY              SUB_SUB_CATEGORY            BRAND
# 0                 MENS WEAR                MEN - T-SHIRTS   PUPPY DOG PALS
# 1            TOYS & HOBBIES                      PELUCHES         ENTRECOT
# 2                AUTOMOTIVE          APARIENCIA AUTOMOVIL            SPURA
# 3                  SEASONAL             SEASONAL - EASTER          CHAMYTO
# 4       HOUSEHOLD CHEMICALS      AIR FRESHENER-DEODORIZER          POOPSIE
# ...                     ...                           ...              ...
# 321537             HARDWARE                   VENTILACION  HO DON CUSTODIO
# 321538       DAIRY PRODUCTS            BUTTER-SUBSTITUTES          MADEMSA
# 321539          ELECTRONICS              EQUIPOS DE AUDIO         DON JUAN
# 321540           92 GROCERY  MILK-CREAM-SUBSTITUTES-SHELF            MEYER
# 321541              SEAFOOD                SEAFOOD - FISH           TAIWAN
#
# [321542 rows x 14 columns]

# %%
Productdata['CATEGORY'] = Productdata['CATEGORY'].str.title()+ '| '+Productdata['SUB_CATEGORY'].str.title()+'| '+Productdata['SUB_SUB_CATEGORY'].str.title()
set(Productdata['DESCRIPTION'])
# Out:
# {'JAMON DE PAVO 1 KG.',
#  'CAFE CAPUCCINO 660 ML.',
#  'THE LEGO MOVIE 2.-PS4 1 PZA',
#  'TERMO 16 OZ ROSA 1 PZA',
#  'CARPA CASTILLO GRIS 1UN',
#  'DULCES MENTA CREMA SIN AZUCAR 75 GRS',
#  'CEREAL TRIX 150 GRS',
#  'BROGAL T ADULTO 120 ML.',
#  'CAFE ORGANICO 500 GRS',
#  'MANTEL DE PLÁSTICO PALA PARY MORADO 1 P',
#  'DURAZNO REBANO EN ALMIBAR 820 GRS',
#  'CHOC ALMENDRAS S/AZ 75GR',
#  'TRESEMME CO OIL RADIANTE 12X750ML 750 ML.',
#  'PL&AACUTE;STICO PARA ENVOLVER 1 PZA',
#  'MUÑECA FAMOSA JAGGETS 700013785',
#  'VJGO PRO EVOLUTION SOCCER 2017 PS3 KONAM',
#  'TAGLIATELLE MOLTO BENNE 250 GRS',
#  'YOGHURT MANGO CEREAL 130 GRS',
#  'PRESONE 5MG. C 10 TABS 1 PZA',
#  'MOUSSE RIZOS PERFECTOS 250 GRS',
#  'MIEL DE MANTEQUILLA 300 ML.',
#  'CONJUNTOS BA 3-6M 1UN',
#  'CREMA CORPORAL CUERPO  UV 25% GRATIS 50M 500 ML.',
#  'PAPAS  CREMA CEBOLLA 149 GRS',
#  'ENDULZANTE SELECTO STEVIA 300 GRS',
#  'ENTEL PLAN BAM 80MB 1UN',
#  'QUESO TORTA DEL CASAR DONA ENGRACIA 400 GRS',
#  'BEBIDA PREMIUM CHINOTTO 200 ML.',
#  'MUCOCEF 500 MG/8.7 MG 21 CAPS 1 PZA',
#  'UVA 500 GRS',
#  'BOTELLA SILICONA 820 1UN',
#  'PALETAS DE FRUTA 280 GRS',
#  'KRUTES JAMON CON QUESO 255 GR CHEF 255 GRS',
#  'RELLENO DE PAVO MR PAVO BOLSA 270 GR',
#  'BRILLO LABIAL FRESA 1 PZA',
#  'REPUESTO PARA RODILLO EXPRESS 1 PZA',
#  'LABIAL LIQUIDO SABOR FRESA 1 PZA',
#  'SET 2 PLATO COM FLOR 1UN',
#  'MOLE POBLANO SALSAVER 500 GRS',
#  'GOTU KOLA CENTELLA ASIATICA 500MG 60 CAP 1 PZA',
#  'PAPEL HIGIENICO MANZANILLA 1 PZA',
#  'POLERA DINO BANDIDO 1UN',
#  'BARBIE DREAMTOPIA HADA BURBUJAS MAGICAS 1 PZA',
#  'VINO TINTO TRAPICHE CABERNET ARG750ML',
#  'SALSA CASERA VERDE COMALENA 360 GRS',
#  'COGNAC LOUIS XIII 1.5 LT.',
#  'CHOCOLATE EN BARRA 43 GRS',
#  'HELADO DIVERTITRENES NUEZ 950 ML.',
#  'BLOQUES LEGO DEPORTIVO DE COMPETICIÓN SU',
#  'MERMELADA DE MANDARINA SICILIANA 340 GRS',
#  'OF.LIMPIADOR MULTIUSOS FLORAL 1LT+200ML 1200 ML.',
#  'BROCHA 3P MULTIPROPO 1UN',
#  'MACETA CEMPASUCHITL CUBIERTA 1 PZA',
#  'AMOBAY C15 500 MG 15 PZA',
#  'BA TM500 1P+TEXT+S 1UN',
#  'ENERGY AND MOOD 113 GRS',
#  'ANATOMICA.SUAVE 10UN',
#  'CJ ORG RIMAX VANITY 14PLG 7575 NAT RSA',
#  'TORT CHOC0GUINDA CG 1UN',
#  'SOBRE DIETRIX',
#  'PIERNA SIN HUESO NAVIDENA 1 KG.',
#  'DURAZNOS EN ALMIBAR MITADES 820 GRS',
#  'SALIDA40-7 1UN',
#  'PACK CAJA CORCHETES 1UN',
#  'PECHUGA DE PAVO SIN SAL 1 KG.',
#  'ADHESIVAS SHARK 1UN',
#  'AGUA  PURIFICADA GARRAFON 19 LT.',
#  'TARIMA ASEPXIA BB MAQUILLAJE POLVO COM 1 PZA',
#  'PLATO FONDO ACRILICO 1UN',
#  'AUDÍFONOS TI POWER AUBT01RJ SPORT BLUET',
#  'POLVO BRONZE TAN 28GR',
#  'BOOST GLUCOSE CONTROL VAINILLA 237 ML.',
#  'NUGGETS DE PECHUGA 292 GRS',
#  'SOFRITO AJO 500GR 500GR',
#  'HARINA BISQUETS QUESO AJO 198 GRS',
#  'ALIMENTO LIQUIDO SABOR ALMENDRA 190 ML.',
#  'SHAMPOO REDKEN 300 ML.',
#  'QUESO REBLOCHON DE VACA EIFFEL .500 GRS 1 PZA',
#  'GOMA DE MASCAR CHICKS ENERGY GUM 8 GRS',
#  'PALETA DE CARAMELO 90 GRS',
#  'OBLEA GRANDE 40 GRS',
#  'CONEJO ROCKLETS TEMPORADAPASCUA 55 GRS',
#  'CRA HADA LABO REDENSIF 50G',
#  'PASTILLAS MENTOS ROLL FRUIT 356 GRS',
#  'BRASSIERE CARNIVAL, ROSA MEDIO, 14',
#  'BOLSAS PARA BASURA MEDIANA 20 S 1 PZA',
#  'CHEETOS TORCIDITOS FAMILIAR\xa0 255G',
#  'QUESO MANCHEGO VILLACENTENO 250 GRS',
#  'ROMPECABEZAS DE MADERA 1 1 PZA',
#  'ESTUCHE BODY MIST ROSA DEI VENTI+ROLL+BD 3 PZA',
#  'AIRE ACONDI CAA8000 1UN',
#  'PANTUFLA MF COR GR L 1UN',
#  'ALF 1.33X1.80 V AZ 1UN',
#  'COCODRILO 1UN',
#  'CREMA AGE PERFECT DE DIA 50 GRS',
#  'MINI PALETAS DE AGUA 0 ML.',
#  'JARABE DE AGAVE FRESA 345 GRS',
#  'HEMPPRO70 SABOR CHOCOLATE 312 GRS',
#  'VINO TINTO ERMITAGE LE PAVILLON 2008 750 ML.',
#  'VINO TINTO FOND DE CAVE MALBEC 750 ML.',
#  'PANECILLOS P/ENSALADA GARDEN HERB 120 GRS',
#  'GALLETAS GAMESA HABANERA INTEGRAL 117GR',
#  'REFRIGERADOR 15 PIES CON DESP. DE AGUA 1 PZA',
#  'ALIN T30 0.75MG 1 PZA',
#  'TOSTADITAS DE MAIZ AL HORNO GUAJILLAS 144 GRS',
#  'AROMATIZANTE REFRESH VERY CHERRY APAR 6',
#  'SHAMPOO OGX NIACIN CAFFEINE 385ML',
#  'HIDRASEC 10 MG GDO SOBR C18 1 PZA',
#  'TARIMA MULTIPRODUCTO 9 1 PZA',
#  'FRIJOL ENTERO BAYO  560 GRS',
#  'PLAYERA PUPPY 35931 2-3X',
#  'SARDINA DESHUESADA S/PIEL EN AC OLIVA 125 GRS',
#  'MANGA USA 45.7CM ATE 1UN',
#  'COJIN JORDACHE KANSAS, CAFÉ MEDIO',
#  "PLATON 15'' GIBSON ARTEMI MARTIN P15584",
#  'SABANA JORDACHE PREMIUM IND BLANCO',
#  'PPS ITALPASTA SPAGUETTI BOLSA 400 GRAMOS',
#  'VINO GRAN CS 14G 750 750CC',
#  'JAMÓN SAN RAFAEL DE PIERNA 250 GR',
#  'TARIMA PERT,HERBAL,H&S JR 07  1 PZA',
#  'SWEATER PERA ANIMAL 1UN',
#  'POLERA EDEN PINK 1UN',
#  'PALITOS TURRON TRADICIONAL 136GR 136 GRS',
#  'ESMALTE SALLY HANSEN INSTA, ESM FLASHY',
#  'ACEITE DE CHIA 60 CAP 1000 MG.',
#  'ILICIT 5-0 CASTANO C 47GR',
#  'TINTE PERMANENTE TONO 66/46 50 GRS',
#  'LECHE CONDENSADA 397GR',
#  'GANCHO SENCILLO POLIETILENO AZUL ARTICO 1 PZA',
#  'JAB TOC C2 CLASICA 1UN',
#  'VINO BLANCO BLANC DE BLANCS 750 PZA',
#  'DESODORANTE AEROSOL CABALLERO  GRAND PRI 1 PZA',
#  'SOPA DE LETRAS ORGNICA 227 GRS',
#  'SHAMPOO CABALLERO 250 ML.',
#  'HUEVO GRANDE EMPLAYADO 1 PZA',
#  'SET PANO TRAFICO 1UN',
#  'SILLA ISO TIZ ESM 1UN',
#  'CAM DORM ML ABU3 1UN',
#  'QUESO PARMIGIANO PORCION 1 KG.',
#  'BEBIDA EN POLVO MELON MAS DURAZNO 38 GRS',
#  'ZAPA NO CAMO NAVY 1UN',
#  '43 DESATORNILLADORES 1UN',
#  'RADICHIO EN HOJAS 1 KG.',
#  'FILIPINA CARFER 40 CIELO CON PANTALON',
#  'SHAMPOO DORA LA EXPLORADORA 400 ML.',
#  'REPUESTO PARA TRAPEADOR ERGO MATIC 1 PZA',
#  'SECC ACAPULCO PU-CEN 1UN',
#  'VINAGRE DE ARANDANO ORGANICO 142 ML.',
#  'TAKIS XPLOSION 280 280GR',
#  'TARIMA DE JUGO PRACTIC 1 LT MINI FULL 3 1 PZA',
#  'VENDITAS 35 PZA',
#  'PIMIENTO MORRON 185 GRS',
#  'SALSA EL CHILERITO CHAMOY PET 355 ML',
#  'SALAMI CACCIATORE 1 KG.',
#  'MAN MASITAS 1 KG 1UN',
#  'RECOVERON G 5G/100 GEL 100ML     N',
#  'TARIMA DE QUINC NOV 2011 1 PZA',
#  'SALSA DE COCO Y GALANGAL  1 PZA',
#  'MAYONESA TIPO SURESTE HERITAGE 312 GRS',
#  'PROTEIN CHOCOLATE 1L 1LT',
#  'MASAS FABRICA HELADO 1UN',
#  'SET 10 GANCHOS PLASTICO AZUL 0716 1 PZA',
#  'MOSTAZA EN PET 226.6 GRS',
#  'CHOCOLATE KINDER MIX DIA NINO 125 GRS',
#  'CENACT RS-250-3 NARJ 1UN',
#  'VINO BLANCO GRAFFIGNA 750 ML.',
#  'OA TINTE DAMA TONO 7.1 Y SH 200ML 588 GRS',
#  'LANZADOR DE AGUA 1UN',
#  'PAY DE QUESO PIA 550 GRS',
#  'HONDA BOLITAS 4UNID. 1UN',
#  'JUGO DE NARANJA ENDULZADO 1 LT.',
#  'MILK LINDOR CORNET. 200GR',
#  'THINS OROWEAT MULTIGRANO FLOW PACK 6 PZ',
#  'HUMALOG MIX25 CCHO 3ML 100UI 2 PZA',
#  'ESPARRAGOS BLANCOS 420 GRS',
#  'LENTEJAS C/TOCINO 400GR',
#  'CAMA REDONDA PARA PERRO 1 PZA',
#  'WHISKY SINGLE MALT 750 ML.',
#  'ZURCAL 20 MG GRAG C/14 1 PZA',
#  'JUEGO DE SARTENES TRAMONTINA MILAN GRIS',
#  'JAMONADA AVE 1KG',
#  'GOMA DE MASCAR ORBIT SIN AZUCAR HIERBAB',
#  'COLADO ORG MAN PLAT 90GR',
#  'LABIAL RENOVA MATTE LABIOS LIQ, ELISA',
#  'ANTIFLUDES JR SOL 60ML 976',
#  'ACONDICIONADOR PARA RIZOS SALVAJES 1 PZA',
#  'TARIMA SHAMPOO Y GEL CABALLERO EGO 1 1 PZA',
#  'WHISKY 12-15ANOS 40G 750CC',
#  'PLAYERA PLAYBOY 31, GRIS MEDIO, G/L',
#  'QG5 30 TABLETAS 2PACK 1 PZA',
#  'ADEREZO HADASA CILANTRO SQUEZE 250 ML.',
#  'DESODORANTE ROLL ON CUERO CRYSTAL 50 ML 1 PZA',
#  'ALGODON 45 GRS',
#  'PANTUFLA SALTO CAMA TOAL, FIUSHA, GRANDE',
#  'JUGO ADICIONADO NECTAR AGAVE AZUL 960 ML.',
#  'JABON DE TOCADOR NEUTRO 150 GRS',
#  'CHOCOLATE RELLENO BOMBON 100 GRS',
#  'TINTURA JFM CASTANO 120GR',
#  'CAFE KAVE DECAF TINS 250 GRS',
#  'BOTELLA MISURA 1.0LT 1UN',
#  'CE PREM 2BD NAPO S/T 1UN',
#  'MARCADOR MAGISTRAL AZOR 4 PZAS + 1 SURT',
#  'BS SUP PRE SUPERK FN 1UN',
#  'ESPUMA PARA AFEITAR 150 GRS',
#  'BIKINI HANES 1302C12 BCO 3 PZ JUVENI, 4',
#  'GALLETA 592 GRS MAS 30 PORCIENTO GRATIS 770 GRS',
#  'POLVO PARA PREPARAR LECHE LATA 375 GRS',
#  'DEBRISAN 60 GRS',
#  'LENTEJA COCIDA 540 GRS',
#  'PAN ARABE TAQUERO 225 GRS',
#  'SACARINA TABLETAS C/500 1 PZA',
#  'LECHE SEMIDESCREMADA 1 LT.',
#  'COLA CAO 180GR 180GR',
#  'LECHE SLAC CHOC LIG 1000GR',
#  'ACONDICIONADOR LOREAL ELVIVE NUTRICION I',
#  'DULCOLAN GRAG 30 1 PZA',
#  'TROZOS SALMON 1 KG 1000GR',
#  'BEBIDA ISLAND CITRUS PUNCH 1892 ML.',
#  'NUTRA MAMA CON OLIVA 250ML',
#  'JABON EN BARRA REVIGORIZANTE 135 GRS',
#  'GUAGUITAS 500GR 1UN',
#  'SUPER SHINE POMADE 113 GRS',
#  'DUOFILM SOL 20 ML.',
#  'BOT ROCKTAGON 22OZ 1UN',
#  'OA TINTE PREFERENCE 4 + MASCARA 59 ML.',
#  'DUSPATALIN 200 MG LP CAPS C28 1 PZA',
#  'LECHE NIDO CLASICA  BOLSA 2200 GRS.',
#  'DUCTAPE 25 METROS 1UN',
#  'BOXER NIÑO DISNEY MICKEY BO1990, 10',
#  'AVELLANAS ASADAS EN MIEL DE ACACIA 240 GRS',
#  'SHAMPOO BOTANICALS EXTRA CUERPO 400 ML.',
#  'TALCO J&J 400 GR ORIGINAL',
#  'DEXTROSA 5% 1000ML PLAST 086',
#  'SALSA KIKKA DE MOSTAZA AL ENELDO 260 GRS',
#  'OA ROLL ON  + MINI FRAGANCIA COORPORAL 50 GRS',
#  'GEL FIJACION FUERTE 1 PZA',
#  'AGUA FINAMENTE GASIFICADA TORONJA 1 LT.',
#  'CREMA CORPORAL HUMECTANTE 200 ML.',
#  'JABON LIQUIDO GREEN OLIVE 300 ML.',
#  '3PACK ANTITRANSPIRANTE REXONA V8 3 PZA',
#  'OA SHAMPOO 2 EN 1 200 ML 30 ML GRATIS 230 ML.',
#  'ALPONT EPAZOTE 25 GRS',
#  'PR BANDERA GENERO 9U 1UN',
#  'CREMA PROTECTORA N SUN F25 1 PZA',
#  'LOCIN ASTRINGENTE ANTIBACTERIAL 150 ML.',
#  'CHOCOLATE PREMIUM 75% RUBIO 85 GRS',
#  'BATID STICK MIX 2616 1UN',
#  'ESTUCHE LOCION Y CREMA Y CREMA MANOS 3 PZA',
#  'GALLETAS TARTALETAS CON RELLENO DE PIÑA 105 GRS',
#  'SHAMPOO 3E1 PJ MASKS 350ML',
#  'VIVO SHOT CHECK 30GR',
#  'OSITO FLANNEL PINK 1UN',
#  'SOYA  ALFA UNO 350 GRS 1 PZA',
#  'MINI JAMON CURADO 900 GRS',
#  'MILANESA RES STERLING SILVER 1 KG.',
#  'TARIMA DE AGUA OXIGENADA 185 ML. 1 PZA',
#  'PEREJIL KG  FS',
#  'CHULETA VETADA 900GR 900GR',
#  'HUMMUS VARIETY PACK 1UN',
#  'LAPICES TINTA 4 FASH 1UN',
#  'CABLE DE AUDIO PLUG-PLUG 3.5 STEREN',
#  'BÓXER MASHA Y EL OSO MABO5',
#  'AGUA CON JUGO UVA 6 PACK MINI 300 ML.',
#  'ENVASE HAMBURGUESA 1UN',
#  'BEBIDA BOING MANGO GEMINA 1 LITRO',
#  'PLUMILLA BB 20 1UN',
#  'CONJUNTO PUPPY 35947 6-18M',
#  'LAPIZ ADHESIVO 2 PZA',
#  'AROMATIZANTE VELA 110 GRS',
#  'CE ORT 1.5P TO CH ST 1UN',
#  'QUESO MANCHEGO NATURAL 300 GRS',
#  'JABON LIQ CORPORAL AROMA ALGODON  425 GRS',
#  'ALIMENTO PARA PASTO GARDENS 1 KG.',
#  'JUGOSO AL SARTEN 24 GRS',
#  'TONYS PEPPERONI PIZZA 4 X 6 129 GRS 1 PZA',
#  'MOZZARELLA STICKS 99 GRS',
#  'ITALVIRON CPR C50',
#  'APRESOLINA 50 MG 50 PZA',
#  'CAFETERA C/TAPA RSXXI CERAMICA BEIGE',
#  'CEREAL CHEERIOS SABOR MIEL 480 GRAMOS',
#  'VASO PARA FRIO-CALIENTE C TAPA 12 OZ. 16 PZA',
#  'PAAL INCONTINENCIA 10 PZA',
#  'UC VERDE CLARO BRILL 1UN',
#  'VASO ECOLOGICO SEMANAL 1 PZA',
#  'CANISTER T/VIDRIO S 1UN',
#  'PALETA LYN PINA 65ML',
#  'CLOSET TUCSON 6P 9C 1UN',
#  'SALSA HABANERA ROJA 180 ML.',
#  'GINEBRA THE GIN FACTORY 700 ML.',
#  'MAFER LATA NAVIDAD 100GR 100 GRS',
#  'CREMA KNORR CHAMPIÑONES TPACK 500GR',
#  'PASTA PARA SOPA MINI PENNE RIGATE 200 GRS',
#  'MANZANA FUJI MALLA 2KG',
#  'RESP S/M 1.5 PL CAFE 1UN',
#  'MIX PINA/NARA/FRUTI 300GR',
#  'PALETA DE DULCE LOONEY TUNES 25 PZA',
#  'CHISTORRA CASA TOLUCA 500 GRS',
#  'TIO NACHO AC MANZ 415ML',
#  'NATURAL CARE G140 140UN',
#  'GELATINA JELLO 25 GRAMOS DURAZNO',
#  'CACEROLA BAJA C/TV VASCONIA 28 CM RUSTI',
#  'CEREAL FROOT LOOPS 550 GRS',
#  'ADEREZO CHIPOTLE 300 GRS',
#  '1004PCCALC HO X2 TR NAN',
#  'POLAR BOTON LE XXL 1UN',
#  'ILICIT 7-1 RUBIO MED 47GR',
#  'LECHE DE SOYA NATURAL SOYAMILKEN 450 GRS',
#  'TINTE NEGRO AZUL INTENSO N52 50 GRS 1 PZA',
#  'RESOTRANS 1 MG 14 TABS 1 PZA',
#  'AC COCO Y JAZMIN DSP 900ML',
#  'BOL CRISTAL C3 3 AZU 3UN',
#  'MALETA AEROLITE AQUARIUS MENTA CH SS19',
#  'CARAMELO CAJITA FIESTA NAVIDAD 133 GRS',
#  'SOMBRA DIAMOND LUST SHEER 2 GRS',
#  'PLATO DIVISIONES.ECO 10UN',
#  'COLCH POLI NOV 2P 1UN',
#  'MERMELADA AIRES DEL CAMPO ORG S/AZ GUAYA',
#  'VINO TINTO MATARROMERA OINOZ 750 ML.',
#  'GERMEN DE GARBANZO 1 PZA',
#  'GALLETAS DE PASTEL DE ZANAHORIA 85 GRS',
#  'LITTLE MOMMY STDO BEBITA RECIEN NACIDA 1 PZA',
#  'JABON LIQUIDO BLUMEN MAN COCONUT CLASIC',
#  'TOALLA FEMENINA ADAPT  C/ALAS 16 PZA',
#  'CARPA 2 PERS 1UN',
#  "PLATO POSTRE 7'' HANGZHOU P15485",
#  'CT PAN PASC F CONFIT 700GR',
#  'BOLSA ECOLOGICA NAV 1UN',
#  'REFRESCO BIPACK 4 LT.',
#  'AZUCAR REFINADA 1 KG.',
#  'CREMA VINTAGE 1UN',
#  'MEDIA TARIMA VIE BABY SUMESA 1 PZA',
#  'DET LIQUIDO ARM & HAMMER FLORAL + OXICLE',
#  'MIX SAL Y ESPECIAS PESCADO 38 GRS',
#  'JABON LIQUIDO PARA MANOS MARACUYA 480 MLL',
#  'JABON DE BARRA DE JITOMATE 100 GRS 1 PZA',
#  'Q. GOU GRA 500 500GR',
#  'CEPILLO DENTAL ORAL B PRO SLD ULTRAFINO',
#  'VINO TINTO NEBBIOLO BATASIOLO 750 ML.',
#  'TALCO ORIGINAL 200 ML 200 GRS',
#  'VEHICULO MEGA BLOKS CAMION DE VOLTEO TRA',
#  'INFLABLE GENERICO 05 1 PZA',
#  'REFRESCO SANGRÍA CASERA 2 LITROS PET',
#  'ACONDICIONADOR ALOE HIDRA BOMB 650ML 1 PZA',
#  'VINO ROSADO FANTINI 750 ML.',
#  'CREMA CORPORAL AVENA EDICION INVIERNO 1 PZA',
#  'JUEGO CUBIERTOS CRISTAL 1 PZA',
#  'SEMILLAS ORGANICAS BEHEMP SALADAS 454 GR',
#  'SOPA POLLO SEMOLA 68GR',
#  'CALAMARES RELLENO AL AJILLO 111 GRS',
#  'DULCE 100 GRS',
#  'FOCO 2U 20W 3000 HRS E27 LF 1 PZA',
#  'PALETAS DE CAJETA 4 PACK 300 GRS',
#  'HELADO NARANJA VAINILLA 1 LT.',
#  'SERMION 30 MG GRAG C20 1 PZA',
#  'PDQ DE NESCAF PROTECT 1 PZA',
#  'PANTALLA 32  FHD SMART 1 PZA',
#  'LOCION DETOXIFICANTE 200 ML.',
#  'FIG TITAN HEROES SERIES 12" WARRIORS 1 PZA',
#  'MI SET DE DIARIO QUALES NEONATOS ROSA N',
#  'ESTUCHE EDT + VASOS TEQUILEROS 100 ML.',
#  'FLONORM 200MG TABS C/28 1 PZA',
#  'LOMO LACHS 125GR',
#  'ESMALTE PARA UNAS BLACK 1 PZA',
#  'FIDEO DE HIUMEN 340 GRS',
#  'MEJILLON CONO SUR 169 GRS',
#  'PANTUF MU SNOOP CELE 1UN',
#  'CARAMELO MORA AZUL Y FRAMBUESA 155 GRS',
#  'TARRO CON LETRA FLORAL 1 PZA',
#  'TUMS T SURT 75 PZA',
#  'CERVEZA OBSCURA GUINNESS 330 ML.',
#  'DESMAQUILLANTE LECHE TODO TIPO DE PIEL 200 ML.',
#  'AS-TRUTRO COMB POLLO 1KG',
#  'PATAS NINA PRINT6 1UN',
#  'PISO SPA BLANCO 1UN',
#  'SOY UNA NIA REBELDE UN DA 1 PZA',
#  'SALSA DE PIA PICANTE 500 ML.',
#  'E PENNE   DE ZITE  RIGATE 500 G IGP 500 GRS',
#  'NICOBLOC 15 ML 1 PZA',
#  'VESTIDO CLARA 1 1UN',
#  'PAY DE DURAZNO JJS 113 GRS',
#  'PICKLE SURTIDO 200GR',
#  'VISTROL 16 MG TAB 20             N',
#  'VINO SB BOT 13.5G 750CC',
#  'CALZA CROP CHARC3W 1UN',
#  'VELA AROMATICA BRISA DE MAR 173GR 1 PZA',
#  'REF NF TX60LE 321L 1UN',
#  'VASOS DESECHABLES 12 ONZ 8 PZA',
#  'BALON SOCCER NO.5 KAPPA NEON 1 PZA',
#  'CEREAL PROBIOTICO 0 NDF',
#  'LECHE EXTRA CALCIO LIGHT 960 ML.',
#  'BB BEAR JOGGER SET 1UN',
#  'PPS LA MODERNA SPAGHETTI BSA 220 GRAMOS',
#  'SANDWICHERA BSM074 1UN',
#  'CEDAX C5 400MG 5 PZA',
#  'PALOMITAS PARA MICROONDAS RANCH 95 GRS',
#  'FD BRB BLRNA ASST 1UN',
#  'B. VOLLEYBALL NO.5 VS-100 MIX NAL 1 PZA',
#  'ESTUCHE VIP AGUA TOCADOR 100ML 1 PZA',
#  'AROM AERO GLADE 323GRS, MANZANA CANELA',
#  'PEPINO PERSA ALFAVID 600 GRS 1 PZA',
#  'SALSA PARA PASTA  ITALIANO 737 GRS',
#  'GOURMET EXENTOS ALIMENTOS PREPARADOS GOU 300 GRS',
#  'CELLCEPT 500 MG C50 MOFETILO DE MICOF 1 PZA',
#  'VINO BLANCO LAMBRUSCO 750 ML.',
#  'AUTO CARRERA 43CM 1UN',
#  'CACEROLA INOX 16X9.5 1UN',
#  'PIÑA EN TROZOS 800 GRS',
#  'REFRESCO 3 POR 2 CALABERITA 2 LT.',
#  'ADEREZO OPA CESAR LITEHOUSE 325 ML.',
#  'CAFE MEDIO MEZCLA DE LA CASA 226 GRS',
#  'ENCHILADOS INDIVIDUA 30 GRS',
#  'TINTE SEMIPERMANENTE COLOR BY YOU PINK',
#  'SAL GOURMET FUSION TRUFA 1 KG.',
#  'ALIM CAR-POL JIRAFA 17KG',
#  'NO BREAK BARRACUDA SR750 6 CONTACTOS',
#  'SHAMPOO ELVIVE RESTAGE 400 ML.',
#  'PATA PRINC ACU2 1UN',
#  'CORRECTOR UNDERCOVER CREMY BEIGE 6 CJA',
#  'SUPER FOODS SEMILLA DE QUINOA INTEGRAL 300 GRS',
#  'FOCO 4 PZA',
#  'CEBOLLIN ENVASADO 1UN',
#  'PASTA DE SEMOLA DE TRIGO CAPPELLI 250 GRS',
#  'PISCINA INF FAMILIAR 1UN',
#  'ESKAPAR 400 MG 16 PZA',
#  'CHOCOLATE AMARGO CON CHILE 100 GRS',
#  'CUBIERTOS DE PLASTICO KIRKLAN  360 PZAS. 0 NDF',
#  'LAVATRASTES LIQUIDO 810 ML',
#  'PRELAVADOR PROTECT PRECIO ESP 4 LT.',
#  'SERVITOALLA MAXI-ABSORB 1 PZA',
#  'PANTUFLA M SUAVE R M 1UN',
#  'TEMPRA 1G 10MG S INY 4X100ML 333 1 PZA',
#  'BARRITAS PIA+BOLSIPACK PRINCIPE CHOCOLA 941 GRS',
#  'HOME DUBAI CAOBA 60P 1UN',
#  'FRUTA CRISTALIZADA TEJOCOTE 1 KG. 1 KG.',
#  'ANTIGRASA DP NARANJA 500 CC',
#  '100 DURAZNO MANZANA 90GR',
#  'ADHESIVO NO MAS CLAVOS FUERTE FACIL 113G 1 PZA',
#  'JUGUE CAÑA N°2 1UN',
#  'TINTE SEMI PERMANENTE TONO  12 53 ML.',
#  'TEMPRA GTS INF UVA 30 ML. 30 ML.',
#  'CHOCOLATE CON LECHE NESTLE POSTRES 150 GRS',
#  'CLOSTEDAL T 20 200MG 20 PZA',
#  'LYCHEE UTEKI EN ALMIBAR 567 GRAMOS',
#  'TABCIN 500 MG EFERV TAB 12',
#  'BANQ ISOCLIP 4TRO GP 1UN',
#  'AFEITADO MAQUINA REGULAR 1 PZA',
#  'FORMULA LACTEA NAN 400 G SIN LACTOSA DE',
#  'COLCHMILENI DOS 1 PL 1UN',
#  'EXTENSION 2RCA-2RCA .90MTS 1 PZA',
#  'MANZANA REBANADA 1 PZA',
#  'LOCION AQUA VELVA ICE AFTER SHAVE 100 ML.',
#  'REFRESCO LIMA LIMON ZERO PET 1 LT.',
#  'TOALLA FEMENINA KOTEX TRIPACK 48 PZA',
#  'CREOLINA 1 PZA',
#  'LECHUGA HIDROPHONICA TRIO 1 PZA',
#  'GALLETAS CON CREMA 210 GRS',
#  'TURRON DE COCO CON CHOCOLATE EXCELLENCE 1 PZA',
#  'KITOSCELL GEL 30G 1 PZA',
#  'B. BASURA 50X70 30UN',
#  'CADENA COMBINACIÓN MASTERLOCK 1.2 M 8147',
#  'CAFE EN CAPSULAS BELLACREMA 50 GRS',
#  'SALERO SAL FINA 125 125GR',
#  'MANTEQUILLA LA ABUELITA S/SAL 225 GR\xa0',
#  'BALERINA STUDS NUDE 1UN',
#  'POLERON SPORT 1UN',
#  'MERTHIOL TINTURA FCO. 30 ML. 0 PZA',
#  'STARS MALVAVISCO 170 GRS',
#  'TOMATE PICADO 190 GRS',
#  'LAT 026.1V MIX STEAK & BBQ GRIGLIATA MI 35 GRS',
#  'GEL ANTIBACTERIAL NEUTRO 200 ML.',
#  'SPRAY 266 GRS',
#  'ADEREZO ASIATICO AJONJOLI TOSTADO 473 ML.',
#  'LABIAL COLOR RICHE PRECIOUS CORAL 4 GRS',
#  'CHOCOLATE BOLSA CORTADOS 100 GRS',
#  'AROMA AUTOMATICO 2 PACK 350 GRS',
#  'BOXER ELAST SURT S 1UN',
#  'SENSACIONES DE PESCADO BLANCO EN SALSA 85 GRS',
#  'SHAMPOO NATURALS HERBAL 900 ML.',
#  'DABEX XR 750 ANTIDIABETICO ORAL 1 PZA',
#  'LECHE SABORIZADA 800 ML.',
#  'MYLINAX 20MG TAB C60 1 PZA',
#  'LUB POCKET UVA 10 ML.',
#  'HIGOS A GRANEL M 1 KG.',
#  'JEAN.CAR.M.L/E.46 1UN',
#  'CHOCOLATE CON ALMENDRA Y  AVELLANA 100 GRS',
#  'PIJAMA PEPPA ML 1UN',
#  'ALIMENTO P/PERRO ADULTO GANADOR PREMIUM 15 KG.',
#  'ZAPATILLA ANIMAL PRI 1UN',
#  'CADUET T 10 5/40 MG 10 PZA',
#  'PLATOS PIRATAS 6UN 6UN',
#  'AGUA DE TOCADOR DAMA MY DELICE 100 ML.',
#  'ESCALERAS DE METAL MODELO YX-DC009',
#  'JABON ALERGIBON INFANTIL 30 GRS',
#  'VENDITAS 20 PZA',
#  'ACEITE DE OLIVA EXTRA VIRGEN SIN FILTRAR 500 ML.',
#  'TRAJE DE BAÑO NISKO 1800',
#  'CINTA FANDELI 18MMX50 M MASKING ADHESIV',
#  'SHAMPOO 3IN1 375ML 375ML',
#  'FACIAL CAJA KIDS 50UN',
#  'BASTON.ANTIROBO TRAB 1UN',
#  'ESMALTE PARA UNAS PRIMAVERA SARA 13 ML.',
#  'PANTALETA ILUSION 1186 M/M NEGRO',
#  'JABON MENNEN 90 GRS',
#  'RAST PRESTOBARBA 5PZ UTRAGRIP, NORMAL',
#  'LIMPIADOR INTERDENTAL 24 PZA',
#  'DIMODAN C 20 100MG 1 PZA',
#  'PANT BB 2PK MONKEY 1UN',
#  'BACILOS PEDIATRICOS C/6 SOBRES 1 PZA',
#  'MOLE NEGRO OAXACA PASTA 1 KG.',
#  'RENOV NOBUCK INCOL 200 ML',
#  'AW PAN CENTENO LINAZ 500GR',
#  'FAMILY PACK 2 PZA',
#  'PACK 2 CONT SNACK 2UN',
#  'TAMAL 580 GRS',
#  'JERINGA PARA INSULINA SUPRAMED 10 PZA 0.',
#  'FRANGANCIA 100 ML THUNDER DORALL 1 PZA',
#  'BIKER SUEDE BLACK 1UN',
#  'VINO ESPUMOSO ZONIN ITA 750 ML',
#  'YODO NEGRO TINTURA 30 ML.',
#  'DISPLAY 6 VASOS LARG 1UN',
#  'AGUA MINERAL BUONA SODA 600 ML.',
#  'CHILES JALAPENOS ENTEROS 265 GRS',
#  'VINO BLANCO SAUVIGNON BLANC DE M LAROCHE 750 ML.',
#  'LABIAL LOREAL COLOR R, CHARME DORE\xa0\xa0\xa0\xa0',
#  'VESTIDO SWEATER 2 1UN',
#  'VINO ME 12G 2LT 2000CC',
#  'BARRA MULTIGRANO MIX DISPLAY CON 8 PZAS 304 GRS',
#  'DESTAC BOSS ROSADO 1UN',
#  'HONGOS ENTEROS 425 GRS',
#  'CR TRAT.OIL REPAIR 3 350GR',
#  'ADEREZO PARA ENSALADA TOCINO - BACON 473 ML.',
#  'ALIMENTO PARA PERROS ADULTOS NATURAL 4 KG.',
#  'PACK CARAMELO BRONCOFRESCH MIEL NARANJA',
#  'CEPILLO DENTAL SLIM SOFT ADVANCED 2PACK 1 PZA',
#  'PLATO DE CARTON NO. 3 20 S 20 PZA',
#  'CEPILLO PARA BIBERON CON ESPONJA 1 PZA',
#  'SNACK NATURE´S HEART FRUTAS ENHILADAS 6',
#  'QUESO CASTELLANO 850 GRS',
#  'PLASTICINA N 1UN',
#  'CAMISA SIMPLE FASH, AZUL OBSCURO, EG/XL',
#  'MARCA LIBRO 2U OSO 1UN',
#  'MESA RECTANGULAR PL. 1UN',
#  'ARMABLE CAPITÁN AMÉRICA: ATAQUE DE LOS O',
#  'TRATAMIENTO CAPILAR SERUM 30 ML.',
#  'DONDE CONQUISTADOR VAINILLA 200GR 200 GRS',
#  'MINIJALADOR 1 PZA',
#  'ILICIT 7-3 RUBIO DOR 47GR',
#  'PLATO SANTA FE 1 PZA',
#  'PATA BLACK COTTON 1UN',
#  'LYRINEL 10 MG 10 PZA',
#  'ESPARRAGO VERDE MARINADO M´LORD 250 GRA',
#  'CREMA PARA PEINAR NUTRI REPAIR 300 ML.',
#  'PAQ.DESODORANTE LADYSSMASCREMA HYDRA66ML 2 PZA',
#  'CEPILLO TIPO OCHO CHICO 1 PZA',
#  'SOLUCION NM DEX 5% 1L 1000 ML.',
#  'SWEATER SH BN GRIS 1UN',
#  'CREMA DENTAL EN GEL ORTODONTICA 75 ML.',
#  'JABON LIQ CREMOSO 1LT',
#  'BOTA QUILT NEGRA 1UN',
#  'AFEIT SG-7290 1UN',
#  'YOGHURT LALA BAT TUNA GUANABANO 150 GR',
#  'GI SUPRAMED MICONAZOL 2/100 GR 20 GR',
#  'TENEDOR Y CUCHARA WARNER 2 PZA',
#  'FRAGANCIA CURIOUS MIST BRITNEY SPEARS DA',
#  'BAFLE 10" 1 PZA',
#  'BALSODERM 150 ML.',
#  'PGR MORPHIN ZORDS 10" 1 PZA',
#  'REFRESCO BI PACK MUNDET MANDARINA Y COCA 1 PZA',
#  'AVENA EN POLVO FORTIFICADA SAB CHOC 375 GRS',
#  'ARANDANOS EN ALMIBAR 410GR',
#  'VINO TINTO SAURUS 750 ML.',
#  'NACHOS 1 PZA',
#  'LAV EF 13.5 K BZG 1UN',
#  'CHOCOLATE LIBRE DE AZUCAR 1 PZA',
#  'TEQUILA BLANCO 750 ML.',
#  'TEQUILA CON TORONJA 355 ML.',
#  'BIBERON EVENFLO 7276 9 OZ',
#  'CREMA SOL.BIONUTRIENT MANZANILLA 110GR 110 GRS',
#  'ESTUCHE CABALLERO EDT 50MLAFTER SHAVE 100 ML.',
#  'TANGA  LOVABLE  8517CH / S NEGRO',
#  'CREMA DE CACAO 1 KG.',
#  'HARINA PAN MULTIPROPOSITO 340 GRS',
#  'RAJA PIMIENTO PUGLIES 314 ML.',
#  'AVENA IQO MORA YOGURT 0% AZUCAR 1 PZA',
#  'TEQUILA 750 ML.',
#  'CHAQ.ENTRE.MUJ.EXP.L 1UN',
#  'ACEIT VINAG SALERO Y PIMENTERA FW P15423',
#  'BRONCOLIPTOS JBE 250ML',
#  'VINO TINTO CAMPO BURGO JOVEN  750ML. 750 ML.',
#  'DELINEADOR ESSENCE DRAW T, HEAD TO TOES',
#  'HAIR MAKE UP  19 BLU 30ML',
#  'AVENA 3 MIN CHOCOLATE BOLSA 300 GRS',
#  'CREST BLAN +SCOPE 2X100ML  JAB PANT GRAT 200 ML.',
#  'MULTIPACK SOLERO LIMON CITRUS 500 ML.',
#  'AROMATIZANTE FMATIC MAGNOLIA 250 ML.',
#  'JUGO VERDE LATA BOTELLA 500 ML.',
#  'LAPICES DE COLOR TWISTABLES 12 PZA',
#  'VINO TINTO DUETTO TEMP MEX 750 ML',
#  'ROCKLETS MANI 18UN',
#  'TINTE PERMANENTE TONO 5.3 233 GRS',
#  'VINAGRE BLANCO 500 500CC',
#  'VINO TINTO DULCE TETRA PACK 1 LT.',
#  'VE PISO-MESA 12 REM 1UN',
#  'CREMA FACIAL SABILA PIEL NORMAL 1 PZA',
#  'CUBREBOCAS DE 3 CAPAS C/25 25 PZA',
#  'QUESO GOUDA POL REBANADO',
#  'AGUARDIENTES DE HIERBAS CASTELO 700 ML',
#  'SCRUB TREE HUT SAL MEDITERRÁNEO 425G',
#  'MERMEL FRUTILLA 200 200GR',
#  'SET SHORT FLAMENCO 1UN',
#  'LIMPIADOR FACIAL 3EN1 150 ML.',
#  'QUESO MANCHEGO PLATA CURADO DON BERNARD',
#  'TRAPEZIO ROJO 750 ML.',
#  'AGUA MINERAL PERRIER 4 PACK DE 330 ML',
#  'COBER\xa0 S/CHOC AMARGO 1000GR',
#  'BRASSIERE MAREL 330, MORADO OBSCURO, 36B',
#  'UVEIL PS PIEL CL 60G 60 PZA',
#  'CEREZA NEGRA EN ALMIBAR 454 GRS',
#  'CHICHARO LIMPIO EMPACADO 1 KG.',
#  'VJGO MORTAL KOMBAT 11 NINTENDO SWITCH',
#  'TAMPON SILK GLIDE 10 PZA',
#  'MAYONESA LITE KOSHER  906 GRS',
#  'MOLDE VASCONIA 26 CM DESMONTABLE',
#  'SALSA VALENTINA PICANTE FRASCO 1 LT',
#  'SECC OBER CHOCO-BUR 1UN',
#  'FOCO LED 4.5/40W FRO 1 PZA',
#  'ANTICAR ZERO 250ML 250ML',
#  'L CARNITINA SUP ALIM CAPS 60 1 PZA',
#  'WS HALLULLA D DOL 1KG',
#  'PIPORTIL L4 AI 1 PZA 1 PZA',
#  'CREMA DENTAL EXTRACTOS NATURALES CARBON 66 ML.',
#  'BIGTIME 7 MENTA 14GR',
#  'GOMA DE MASCAR CONFITADA SABOR CEREZA 320 GRS',
#  'LAPIZ GEL 2 1UN',
#  'ALIM SECO RAZA MG 15KG',
#  'SILLA PLEGABLE LICEN 1UN',
#  'PLAYDOH ONE PACK 1UN',
#  'DETERGENTE ROPA LIQ FRESCA 5 LT.',
#  'TIN CANNON UNISEX 5 PZ',
#  'SALCHICHA DE PAVO GRANEL 1 KG.',
#  'COMODA CRISANTE 1UN',
#  'V LOMO LISO CHURRASC 1KG',
#  'B OR B5BK 1.5 LEG ST 1UN',
#  'CAFE TOST Y MOLIDO VAINILLA 283 GRS',
#  'SALSA DE TOMATE ORGANICA 425 GRS',
#  'FORMULA LACTEA  SMA GOLD 900 GRS',
#  'OMO POLVO A VERA 5KG',
#  'BLOQUEADOR FP30 PGRAL 120ML 1 PZA',
#  'TOALLITAS LIMPIADORAS DESINFECTANTES 0 NDF',
#  'MONDADIENTES 150 TAR 150UN',
#  'NULYTELY PVO SOB 4 110.1GLIMAL 1 PZA',
#  'MOSTAZA DE HIERBAS DE PROVENCE 200 GRS',
#  'CERVEZA CORONA CLARA 4 PZS LATA 473 ML',
#  'ANGLOPEN T 12 1G 12 PZA',
#  'EXTRACTO NATURAL DE VAINILLA 250 ML.',
#  'COJIN EVITA REFLUJO 1UN',
#  'AVENA QUAKER INSTANT MORASYOGURT 0%AZUCA',
#  'LIMPIA VIDRIOS WINDEX 1 GAL 0 NDF',
#  'MASCARA PARA PESTANAS CLUMP CRUSHER 13.1 ML.',
#  'TARIMA DE PRELAVADORES EL MAGO JR 2014 1 PZA',
#  'MAQUILLAJE EXPRESS STICK SHINE CONTROL 4 GRS',
#  'WIPES DESINF. BAÑO 35UN',
#  'HEMP BITES SABOR ORIGINAL 45 GRS',
#  'DESODORANTES PARA CABALLERO 90 GRS',
#  'PALETA ROCKALETA JUNIOR 100 GRS',
#  'POLERA OSAKA 1UN',
#  'GALLETAS SAVOIARDI 500 GRS',
#  'PIMIENTA ROSA SECA 25 GRS',
#  'PALETA AGUA POPSICLE 650 ML.',
#  'VINO ESPUMOSO CUNE CAVA BRUT ESP 750 ML',
#  'SALAMI ZWAN PEPERAMI ORIGINAL 23 GR',
#  'SET 6 COPAS VINO TTO 1UN',
#  'SUCCULENT PALITOS DE PAN 60 GRS',
#  'YOG. OIKOS F.ROJO TR 110GR',
#  'COMPLETE LIFT 15 ML.',
#  'KIT CEPILLO WALFORT PORTAB D VIAJE LIMPI',
#  'JARRA AGUA CUAD 1UN',
#  'ALUBIAS CON CHORIZO 425 GRS',
#  'LAMPARA DULUX EL MICRO TWIST 23W/830 BL 1 PZA',
#  'IMOT 0.50 SOL OFT MALEATO 15ML 1 PZA',
#  'DESMAQUILLANTE DUO 100 ML.',
#  'ANTITRANSPIRANTE AMMENS 2PIECE 2 PZA',
#  'TIN CANNON 1918',
#  'SALAMI TIPO HUNGARO',
#  'CHOCOLATE SNACK BAR 22 GRS',
#  'GALLETAS CHISPAS DE CHOCOLATE SIN AZUCAR 112 GRS',
#  'DOLO TANDAX SUSP 100 ML.',
#  'VINO ESPUMOSO ASTI ITA 750ML',
#  'LONCHERA DRAGON BALL Z 1 PZA',
#  'PAPILLA ULAN 113 GRS',
#  'PLANEADOR MAGNÉTICO BORRADO EN SECO',
#  'PACK CEPILLOS 3D WHITE 5 PZA',
#  'TAPON NEGRO 2 1/4 . 1UN',
#  'VINO TINTO HENRI DE VILLAMONT NUITS SAIN',
#  'BRILLO LABIOS JET STREAM STRAWBERRY D 1 PZA',
#  'BC CAPASILLOS - BONITA EN ROSA',
#  'ANTITRANSPIRANTE EN AEROSOL PARA CABALLE 150 ML.',
#  'LIBERTRIM 200MG CPR C48',
#  'LED CLASSIC 9W LUZ FRIA 1 PZA',
#  'SNACK MIX MGA 10 1UN',
#  'GALLETAS TARTALETA ZARZAMORA 52 GRS',
#  'BEBIDA EN POLVO TE HELADO DE LIMON 85 GRS',
#  'DABEX XR 500 MG TAB 30',
#  'NEUMATICO 175/70R13 1UN',
#  'CLAVO ENTERO 25 GRS',
#  'RALLADOR PEQ INOX 1UN',
#  'INFUSIN  MANZANILLA GRANEL 100 GRS',
#  'CREMA DE VINAGRE BLANCO 500 ML.',
#  'FILETE DE ARENQUE EN  CREMA DE HIERBAS 200 GRS',
#  'PLAYSET FIGURA BASIC 1UN',
#  'CARDON, REMEDIO HERBOLARIO HÍGADO 25 SOB',
#  'CAFE LIOFILIZADO GOLD 180 GRS',
#  'BEL ARA PASITA ENCHILADA 250 GRS',
#  'GOMA DE MASCAR PARTI MIX 57 GRS',
#  'REDERMIC PIEL NORMAL-MIXTA 40 ML.',
#  'VELA N 5 LIDER 1UN',
#  'ACHICORIA 1UN',
#  'REFRIG NO FR 250 LT 1UN',
#  'SHAMPOO CUIDADO CLASICO 2 EN 1 750 ML.',
#  'JALEA PETALOS DE ROSA 245 GRS',
#  'VINO TINTO SURCO 2,7 750 ML.',
#  'JAMON ACA 250GR',
#  'AGUA MINERALIZADA 8 PACK 235 ML.',
#  "CALADRYL'S LOC 180ML",
#  'BIKINI HANES 1302C12 BCO 3 PZ JUVENI, 14',
#  'PREPARADO DE PAELLA DE ABANDA 850 GRS',
#  'MAQUILLAJE ASEPXIA BB CREM, BEIGE CLARO',
#  'CUELGA PUERTA CASC M 1UN',
#  'REFRESCO MANZ 10X7GR 10UN',
#  'CEREAL BRAN FLAKES 540 GRS',
#  'PLATO DE CARTÓN 4FUN DINOSAURIOS 8 PZ 7P',
#  'SCALDA SENSI MX MAT 1UN',
#  'TAMAL CON POLLO  5 PZAS. LA CHOZA 500 GRS',
#  'BETABEL COCIDO PELADO 1 PZA',
#  'MANTEQUILLA 500 GRS',
#  'PATATILLA NA LTPINK 1UN',
#  'ESPATULA TASTY 1UN',
#  'ARROZ HONGOS PORCINOS 1 PZA',
#  'VINO TINTO CRIANZA 2002 750 ML.',
#  'COMEDOR ANDRES 4S 1UN',
#  'LABIAL INFALLIBLE LE GLOSS CORAL SANDS 6 ML.',
#  'TARIMA DE 504 PZAS 1 PZA',
#  'TARIMA DE VOLTAREN SOFTGEL 25 MG 20 CAPS 1 PZA',
#  'BEBIDA EN POLVO LIMA LIMON 1 PZA',
#  'PILA ALCALINA AAAX6 6GR',
#  'SIDRA ROSADA 290 ML.',
#  'PLATO COMIDA 28CM 1UN',
#  'CORT. MALLORCA T1565 1UN',
#  'PULPO EN ACEITE DE OLIVA EXTRA 1 PZA',
#  'CHOCOLATE CORTADOS 12 PZAS 115 GRS',
#  'VINO ESPUMOSO FOUR PACK 1 PZA',
#  'FILTRO CONICO 4 40 PZA',
#  'GANADOR DE MASA MUSCULA VEGETAL ONE NAT',
#  'RELOJ PROYECTOR SPID 1UN',
#  'VJ THE LEGEND OF ZELDA BREATH OF TH 1703 1 PZA',
#  'FIBROXOL BEZAFIBRATO 200 MG CAJA CON 30 1 PZA',
#  'MERMELADA DE FRUTAS 5 PZA',
#  'MEZCLA ALIMENTOS VERDES CURCUMA ORGANICA 100 GRS',
#  'SET MAQUILLAJE PALET 1UN',
#  'ADITIVO PARA GASOLINA 300ML CHD',
#  'TALCO TRADICIONAL FLORAL 250 GRS',
#  'PACK XPRIME 397 GRS',
#  'CHOCOLATES BOMBONES 300 GRS',
#  'MAS DELICADA 2 LT MAS 250 ML GRATIS 2500 ML.',
#  'JABON TOCADOR GRANADA/PROTEINAS 90 GRS 1 PZA',
#  'DETERGENTE EN POLVO REGULAR 2 KG',
#  'EST ITZY POP + COSM 1UN',
#  'SET INFANTIL 4 PZAS LOCIONBRILLOCREMA 1 PZA',
#  'ACONDICIONADOR NUTRITIVO Y REPARADOR 500 ML.',
#  'SARTEN CM TRAMONTINA',
#  'BONBON BLANCO 1 PZA',
#  'MEDIA PANT CHAMPAGNE 2UN',
#  'GALLETA DE CANELA Y PASAS 62 GRS',
#  'CUADERNO SCRIBE PROFESIONAL KIDS, C7',
#  'KENT SILVER 20 UN',
#  'TE CHAI NP 25 GRS',
#  'GEL 300 ML.',
#  'LECHE LIGHT U.P. 1 L 1 PZA',
#  'TABLA DE CORTAR PEQ 1UN',
#  'VINO TINTO DADA 3 ARG 750ML',
#  'PLAYERA JORDACHE AALS 04',
#  'AMANTADINA CLORFE-PARA GI C/24 CAPS 1 PZA',
#  'VENTILA TECH  M56LGS 1UN',
#  'TREN THOMAS FRIENDS MONKEY PALACE PLAYSE',
#  'PANT CAB SNOOPY 2 1UN',
#  'CHILE SECO CHEDRAUI ANCHO BOLSA 100 GR',
#  'TARIMA DE ALIMENTO DE SOYA  ADES 1 PZA 1 PZA',
#  'MACARELA EN TOMATE 425 GRS',
#  'SUECO EVA M PDQ1 M 1UN',
#  'SOMBRAS P/OJOS PALETA NUDES 6.5 GRS',
#  'FILETES DE ANCHOAS EN ACEITE DE OLIVA 48 GRS',
#  'SHAMPOO SWISS SPA ALOE VERA 591 ML.',
#  'CANELA MOLIDA FRASCO 70 GRS 70 GRS',
#  'GOMA HI POLYMER BLANCA 5PZ',
#  'PAN CANADIAN BAGELS MUFFINS 6 PIEZAS 390',
#  'JARABE DE MAPLE 236 ML.',
#  'SPRAY DESODO SUSPIRO INTIMO SUMMERS EVE 43 GRS',
#  'GLORIAS CON NUEZ 5 PZAS 150 GRS',
#  'PATIN GO PLAS BOTA MINNIE V2/V3 T21 7138',
#  'CREMA EN GEL HIDRATANTE 24H 50 ML.',
#  'SAZONADORES SAL SAZONADORA PARA CARNE 100 GRS',
#  'HOJAS PLATANO 1 KG.',
#  'PUZZLE ANIMALITOS 1UN',
#  'COJIN JOMARA 0275 UNITARIO',
#  'CREMA PARA MANOS Y UAS MIEL Y JALEA REA 1 PZA',
#  'LABIAL XPERIENCE PURPLE 2 GRS',
#  'PANTALON DISNEY \xa00561',
#  'GUANTES COMFORT AND CARE MEDIANOS 1 PZA',
#  'SEGUETA TRUPER BIMETÁLICA P/ARCO 2PZ',
#  'PATA CORAL PINAS2 1UN',
#  'BIKINI BOT SIM TERRA 1UN',
#  'ADEREZO 272 ML.',
#  'POLAR BA LILA 1UN',
#  'PK2 BODYS BCO 1UN',
#  'FLASH MULT CON ACEITE DE PINO 3780ML 3780 ML.',
#  'JOCOQUE SECO EN ACEITE 270 GRS',
#  'PAN INTEGRAL CON MIEL Y CEREALES 475 GRS',
#  'TABLET MPAD T3 10 WF 1UN',
#  'VINO TINTO RVA. 750 ML.',
#  'BEBIDA EN POLVO HORCHATA 675 GRS',
#  'BOTANAS PITA CHIPS CON CHIA 226 GRS',
#  'FULCIN-FORTE 500 MG 30 PZA',
#  'BEBIDA DPORTVA 600 ML.',
#  'ACE OLIVA PURO OLI BOT  500 ML',
#  'LECHE PAST. SABORIZADA CHOCOLALA 1 LT.',
#  'SHAMPOO MARC ANTHONY 250ML MACADAMIA',
#  'CHOCOKRISPIS TE REGALA SOBRE DE CAFE ORO 750 GRS',
#  'PG LABIAL HYDRA602 1UN',
#  'SET 12 SERV CIRCO 12UN',
#  'ESTUCHE DE LACTANCIA CON 3 ART 1 PZA',
#  'BEBIDA BOING NARANJA GEMINA 1 LITRO',
#  'SERV. COCKTAIL ESTI 200UN',
#  'MAQ COSER CS6000I 1UN',
#  'LOCION P/LINEAS DE EXPRESION/CONTORNO OJ 0 NDF',
#  'PLENDIL T 10 5MG 10 PZA',
#  'ESMALTE L.A. COLORS GEL UÑAS MADEMOISELL',
#  'JAMON VIRGINIA BAFAR PAQ. 200GR 1 PZA',
#  'BA TM5002PDIV+TE+S 1UN',
#  'GRANOLA FRUTOS SECOS 340GR',
#  'GANCHO HIDRO RAF 5 PZAS SUPER VARIOS COL',
#  'MASTER DOG HUESITOS 65GR',
#  'CUADERNO DIETRIX COLLEGE 100 H C5 FRRDO',
#  'ALP NA MACRAME BEIGE 1UN',
#  'CABESTRILLO SENCILLO GDE',
#  'ROMERO DAILY 1 PZA',
#  'CHALECO DUNLOP 9023, NEGRO, EG/XL',
#  'ASTRINGENTE TRIPLE ACCION CON EXFOLIANTE 250 ML.',
#  'PK2 BODY CUELLO BN 1UN',
#  'VASO TERMICO # 10 20 PZA',
#  'GALLETA DE FRESA DADDY RAYS 283 GRS',
#  'TINTE CAOBA N55 137 GRS',
#  'SALSA DE SOYA 180 ML.',
#  'GELATINA EN POLVO SABOR UVA 84 GRS',
#  'UC BLANCO SEMI BRILL 1UN',
#  'BACTERICIDA BACDYN PLUS 20 ML.',
#  'CARPA PLAYA POP UP A 1UN',
#  'BLODIVIT 10MG TABLETAS C/30 1 PZA',
#  'LABIAL INFALLIBLE X3 ROJO QUEMADO 3.7 ML.',
#  'SALSA TOMATE SACHET 1200GR',
#  'CHISTORRA OBERTAL .300 GRS 1 PZA',
#  'CHOCOLATE LARIN TENTACIONES CUBO 12 PZA',
#  'PASTELITOS CON CREMA DE LECHE 350 GRS',
#  'DVD LIQUIDACION 1.00 1UN',
#  'POUCH PAPILLA PERA 113 GRS',
#  'VINO TINTO CHATEAU GAZIN POMEROL  750 ML. 750 ML.',
#  'POLVORON CACAO 1 PZA',
#  'TAZA DEC ECONOM FLUJ LIBR 8OZ 1 PZA',
#  'CUNA HOME LINE BABY',
#  'COLADO DE MANZANA C/PLATANO TERCER ETAPA 175 GRS',
#  'LAPIZ DELINEADOR DE CEJAS 1 GRS',
#  'OMEGA 3 ACEITE DE PESCADO 90 PZA',
#  'OLLA DE PRESION 8 LITROS ALUMINIO TFAL 1 PZA',
#  'PORTA LAPTOP SWISSMOBILITY TIG-115BK NE',
#  'ESTUCHE FRAGANCIA SWISS ARMY 2 PZA',
#  'SURTIDO DE TE 0 NDF',
#  'TEQUILA 1 PZA',
#  'ACEITUNA MANZANILLA SIN HUESO 350 GRS',
#  'CHAMARRA BORDADA 1 PZA',
#  'ENVASE DE AGUA 1 LT.',
#  'AZUCAR  BC 3 KG 0 NDF',
#  'BODY LOTION C BOOTH COCO HIGO 473ML',
#  'MOSTAZA ACEITE DE OLIVA/BALSAMICO 133 GRS',
#  'TRAPERO MICROFIBRA 1UN',
#  'AFTER SHAVE BALSAM SENSITIVE 1 PZA',
#  'CHOCOLATE L´ATELIER 70% CACAO BARRA 1 P',
#  'VINO BLANCO 1.5LT 1500CC',
#  'TRATAMIENTO PARA UNAS 10 ML.',
#  'AGUA MINERAL S/GAS 600CC',
#  'DETERG  LIQ BOTELLA 3000CC',
#  'EXT USO RUDO DE 2.00 M CAL 2X16 COND ROS 1 PZA',
#  'DELINEADOR ESSENCE LONG LA, PURPLE RAIN',
#  'ALPARGATA HO NAVY 1UN',
#  'SAZONADOR PARA AVES 71 GRS',
#  'LANZADOR NERF DARTFIRE B8246',
#  'MAQUINA AFEITAR EXCELL WOMAN FASHION 1 PZA',
#  'SALCHICHA SABORI PAVO KG',
#  'SHERBET DE LIMON 1 PZA',
#  'FALAFEL Y SALSA TAHINE 470 GRS',
#  'ENDULZANTE SELECTO STEVIA 100 GRS',
#  'SERVILLETA CHICA PIC NIC PLAID 24 PZA',
#  'LIPTON 100BOLSAS 1UN',
#  'RASURADORA RECARGABLE MACH 3 1 PZA',
#  'ZAPALLO ITALIANO ORG 1UN',
#  'EMPANADA QUESO TRAFI 280GR',
#  'PLUMILLA BB 26 1UN',
#  'POP TARTS FRENCH TOAST 8PZS 416 GRS',
#  'SUERO MUSTELA MATERNIDAD CORRECCION ESTR',
#  'BASE MAQ LOREAL INFAL, NATURAL BEIGE, SB',
#  'TAVANIC T 7 500MG 7 PZA',
#  'BL.3GOMAS CUATRICOLO 1UN',
#  'CARAMELOTUTI FRUTI 40GR',
#  'ZAPATI LONA M LEOPAR 1UN',
#  'PEREJIL LIDER. 12GR',
#  'VODKA BELVEDERE PURE 700 ML.',
#  'FRUTIYA ENSALADA CITRICA 198 GR PZA',
#  'BOXER NIÑO DISNEY MICKEY  BO2002, 10',
#  'PAN WHOLE GRAIN AND OAT  680 GRS',
#  'MOCHILA PHOTO PACK KIND TEENAGE MUTANT',
#  'SWEATER ACUREPEAT10 1UN',
#  'TÉ HOJA FLOR DE LA PAZ 27 GRS BIENESTAR',
#  'PAQUETE CLUB 1150 GRS.',
#  'OA TINTE DAMA TONO 5.15 Y SH CR 200ML 506 GRS',
#  'GEL ATM MACHO ALFA PARA CABELLO 1 PZ 90',
#  'SOMBRA DIAMOND GOLD 2 GRS',
#  'CREMA LIQ + TONICO+ TOALLAS LIMP 3 PZA',
#  'FREIDORA ELECTRICA 1 1UN',
#  'CREMA.CORPORAL.HUMEC 950ML',
#  'FROOT LOOPS L BONUS PACK 540 GRS',
#  'AEROSOL MAXTOOL AZUL REY 300ML',
#  'HEL PREM VAINI S/L 800CC',
#  'CREMERO NUEZ Y CARAMELO 946 ML.',
#  'SALES PARA BAÑO YLUX MENT, LAVANDA',
#  'CHOCOLATE PREMIUM 213 GRS',
#  'CHOCOLATE KISSES ALMENDRAS TRICOLOR 1 PZA',
#  'TEMP FRANCIA VERD250 1UN',
#  'LPIZ DELINEADOR D/OJOS INNOVA NEGRO 1 GRS',
#  'PORTA 3 TEALIGHT 1UN',
#  'ESTUCHE PADRES ADIDAS UEFA AGUA TOC 100 1 PZA',
#  'YOGHURT OIKOS MANGO MANDARINA 225G',
#  'CHOC BAILEYS TUBO 200 GRS',
#  'LABIAL COLOR RICHE STAR SECRETS 36 GRS',
#  'JEAN.CAR.M.L/E.52 1UN',
#  'ACU JEANS BN DK 1UN',
#  'LIMPIADOR ESPECIALIZADO COCINA 1 LT.',
#  'SHAMPOO CLASICO 200 ML.',
#  'STEVIA 100 GRS',
#  'PAÑAL INCONTINENCIA SLIP GDE TRIPACK 24 PZA',
#  'MERMELADA 4 FRUTAS 283 GRS',
#  'CREMA AL CACAO CON AVELLANA 1 SABOR 210 GRS',
#  'MERMELADA DE SINFONIA DE FRUTAS 340 GRS',
#  'CERVEZA 1906 RESERVA ESPECIAL 330 ML.',
#  'ENTERITO DARIA OLIVE 1UN',
#  'AGUA DE PERFUME AQUA DI FIORI 8 ML.',
#  'GEL RADIANCE 150ML',
#  'QUITAESMALTE DE 100ML + 50ML ENDURECEDOR 2 PZA',
#  'BOXER NIÑO DISNEY MICKEY  BO1998, 4',
#  'SILICON ULTRA DURABLE TRANSP VENTANAS 289 ML.',
#  'KIT DE ANEJAMIENTO BARRICA 1 PZA',
#  'ENCONTROPINA 10/20 MG TAB 20',
#  'EAT SMART STICKS 200GR 200 GRS',
#  'SOPA MEXICANA DE 95 GRS',
#  'VINO PINOT/CS 13G 750CC',
#  'TROLLEY RAIDER 1UN',
#  'PAN BLANCO STROEHMANN 660GR 660 GRS',
#  'DG LATTE MACCHIATO 194GR',
#  'ALARMA FULGORE ANUNCIA C/SENSOR FU0793',
#  'CREMA DE 9 VERDURAS ORGANICA 1 LT.',
#  'COCHE PARAGUA 1UN',
#  'PASTILLAW.C C/CLORO 45GRS.M.P. 45 GRS',
#  'BEBIDA DE SOYA ORGANICA  KOSHER NATURAL 946 ML.',
#  'MALVAVISCO 10/624 GRS 624 GRS',
#  'QUESO BRIE 250 GRS',
#  'CHOCOLATE CALABACITA HALLOWEEN 85 GRS',
#  'ACONDICIONADOR COLOR RADIANTE 500 ML.',
#  'VODKA LORANGE 700 ML',
#  'TRATAMIENTO CAPILAR 240 ML.',
#  'HUEVOS PRIMERA CAFE 12UN',
#  'MORDEDERA FUNNY 1 PZA',
#  'REFRESCO MANGO 2500 ML.',
#  'VINO CARMENERE 13G 750CC',
#  'SALSA KIKKOMAN SRIRACHA 301 GRAMOS',
#  'BABERO IND NA1 1UN',
#  'CREMA REAF 350 350ML',
#  'CHOCOLATE CNC 12%MAS 48 GRS',
#  'CREMA DE MELON 250 GRS',
#  'SARDINA ESTILO PORTUGUES 120 GRAMOS',
#  'LIGAS SCUNCI PARA CABELLO VALUE PACK 60',
#  'ALMOHADA KALTEX HOME RAYAS BLANCO 2 PZ',
#  'MARATON POCKET 1 PZA',
#  'SOFA GREZ 3C T-ORO 1UN',
#  'ENS APIO VARA 500GR 500GR',
#  'CHOCOLATE SEMIAMARGO 300 GRS',
#  'LIMPIADOR DE LENGUA 1 PZA',
#  'SMARTPHONE HISENSE V3 16GB, MORADO',
#  'COMENTER   10 COMP 15 MG ASOFARMA',
#  'ROLI  BOTANA PALOMITAS 90 GRS',
#  'SAND BIRK CLAS WHITE 1UN',
#  'ALCACHOFA EL SERPIS FONDOS 390GR',
#  'PASTELITO HIP-HOP 2 PZS 65 GRS',
#  'PAN DE QUESO ORIGINAL 210 GRS',
#  ...}

# %%
Productdata['Package'] =  np.select(
            [
                Productdata['DESCRIPTION'].str.contains("UN"),
                Productdata['DESCRIPTION'].str.contains("KG"),
                Productdata['DESCRIPTION'].str.contains("LT"),
                Productdata['DESCRIPTION'].str.contains("PZA"),
                Productdata['DESCRIPTION'].str.contains("ML"),
                Productdata['DESCRIPTION'].str.contains("GRS"),

            ],
    [
        'UN',
        'KG',
        'LT',
        'PZA',
        'ML',
        'GRS'
        
    ],
    default = 'N/A'

)

# %%
del Productdata['SUB_CATEGORY']
del Productdata['SUB_SUB_CATEGORY']

# %%
Productdata
# Out:
#            SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 0        52572       UN                  B          N/A         False
# 1       278100      N/A                  R          N/A          True
# 2        27404       KG                  B          N/A          True
# 3       215143       UN                 CD            Y          True
# 4        85805       KG                 CD            N         False
# ...        ...      ...                ...          ...           ...
# 321537   37542       UN                N/A            N         False
# 321538  199851      N/A                  R            Y          True
# 321539  144269      N/A                  R            Y          True
# 321540  312844       KG                  B          N/A          True
# 321541   60891       UN                N/A          N/A          True
#
#         FINELINE_NUMBER       BARCODES                                 NAME  \
# 0                713115   693177767936                             CANASTOS
# 1                345827            399                   LIMÓN COLIMA KG
# 2                134923   762230099043                              CHICLES
# 3                773663  7501199416236  JABON LIQUIDO PARA MANOS VITAMINA E
# 4                233313  8410113003119   VINO TINTO GRAN CORONAS TORRES 750
# ...                 ...            ...                                  ...
# 321537           966232   698400300544                      LOZA BASICA GRA
# 321538           855034  7501199404301             DETERGENTE LIQUIDO COLOR
# 321539           434058  7501006555752      2 SOBRES PALOMITAS  + VALENTINA
# 321540           305744  6971165068775     CAMISA JORDACHE J, BLANCO, EG/XL
# 321541           975067    40000695373                                 SOFA
#
#                                         DESCRIPTION  \
# 0                           CANASTO CONEJO F1 A 1UN
# 1                                LIMÓN COLIMA KG
# 2                             TRIDENT 6S SANDIA 9GR
# 3       JABON LIQUIDO PARA MANOS VITAMINA E 442 ML.
# 4          VINO TINTO GRAN CORONAS TORRES 750 1 PZA
# ...                                             ...
# 321537                       TAZA CONSOME 280CC 1UN
# 321538                DETERGENTE LIQUIDO COLOR 5 LT
# 321539        2 SOBRES PALOMITAS  + VALENTINA 1 PZA
# 321540             CAMISA JORDACHE J, BLANCO, EG/XL
# 321541                      SOFA SOC T-PU CHOCO 1UN
#
#                                                 IMAGE_URL  \
# 0       https://locahost:8000/images/693177767936?heig...
# 1       https://locahost:8000/images/399?height=500&wi...
# 2       https://locahost:8000/images/762230099043?heig...
# 3       https://locahost:8000/images/7501199416236?hei...
# 4       https://locahost:8000/images/8410113003119?hei...
# ...                                                   ...
# 321537  https://locahost:8000/images/698400300544?heig...
# 321538  https://locahost:8000/images/7501199404301?hei...
# 321539  https://locahost:8000/images/7501006555752?hei...
# 321540  https://locahost:8000/images/6971165068775?hei...
# 321541  https://locahost:8000/images/40000695373?heigh...
#
#                                                  CATEGORY            BRAND  \
# 0       Apparel| Mens Wear| Men - T-Shirts| Mens Wear|...   PUPPY DOG PALS
# 1       Entertainment| Toys & Hobbies| Peluches| Toys ...         ENTRECOT
# 2       Hardlines| Automotive| Apariencia Automovil| A...            SPURA
# 3       Hardlines| Seasonal| Seasonal - Easter| Season...          CHAMYTO
# 4       Consumables| Household Chemicals| Air Freshene...          POOPSIE
# ...                                                   ...              ...
# 321537  Hardlines| Hardware| Ventilacion| Hardware| Ve...  HO DON CUSTODIO
# 321538  Grocery| Dairy Products| Butter-Substitutes| D...          MADEMSA
# 321539  Entertainment| Electronics| Equipos De Audio| ...         DON JUAN
# 321540  Grocery| 92 Grocery| Milk-Cream-Substitutes-Sh...            MEYER
# 321541  Meat & Fish| Seafood| Seafood - Fish| Seafood|...           TAIWAN
#
#        Package
# 0           UN
# 1           KG
# 2          N/A
# 3           ML
# 4          PZA
# ...        ...
# 321537      UN
# 321538      LT
# 321539     PZA
# 321540     N/A
# 321541      UN
#
# [321542 rows x 13 columns]

# %% [markdown]
# ## Findings
#
# - __Branch__ information is not available for 19.96% of the record. Upon analysis, we decided to remove those records as it did not give any significant insight to the data. Sample rows has been attached in the email.
# - __BUY_UNIT__ is not available for 34% of the records. We have marked those records as Not Avaliable (N/A).
# - __DESCRIPTION_STATUS__ is not available for 20% of the records.We have marked those records as Not Avaliable (N/A).
# - __ORGANIC_ITEM__ is not available for 33% of the records.We have marked those records as Not Avaliable (N/A).
# - We were able to findout __Package__ information like _'UN'_,_'KG'_,_'LT'_,_'PZA'_,_'ML'_,_'GRS'_ from description. Please provide list of all packages that we have so that we can clean and add remaining packages.
